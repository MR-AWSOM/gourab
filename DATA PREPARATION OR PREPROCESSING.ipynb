# %% [markdown]
# # <u>DATA PREPARATION /DATA PROCESSING
# - 2 STEP APPROACH
#     - 1) DATA CLEANING :- drop,dropna

# %% [markdown]
# ## 1) import library

# %%
import pandas as pd

# %% [markdown]
# ## 2) import data

# %%
weather_data = pd.read_csv("data_clean.csv")

# %%
weather_data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %% [markdown]
# ## 3)Data understanding

# %% [markdown]
# ## 3,1) initial analysis

# %%
weather_data.shape
# Out:
# (158, 10)

# %%
weather_data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
weather_data.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
weather_data.drop(['Unnamed: 0','Temp C'],axis=1)
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
weather_data.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %% [markdown]
# ## 4) DATA PREPARATION

# %%
weather_data.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
38/158*100
# Out:
# 24.050632911392405

# %%
weather_data['Ozone'].mean()
# Out:
# 41.583333333333336

# %%
weather_data['Ozone'].median()
# Out:
# 30.5

# %% [markdown]
# # lets take client rehan has approved togo with median imputation for Ozone features

# %%
weather_data['Ozone'].fillna(value=30.5,inplace=True)

# %%
weather_data.isna().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       7
# Wind          0
# Temp C        0
# Month         0
# Day           0
# Year          0
# Temp          0
# Weather       3
# dtype: int64

# %%
weather_data.head(30)
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0            1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1            2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2            3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3            4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4            5   30.5      NaN  14.3     56     5    5  2010    56       S
# 5            6   28.0      NaN  14.9     66     5    6  2010    66       C
# 6            7   23.0    299.0   8.6     65     5    7  2010    65      PS
# 7            8   19.0     99.0  13.8     59     5    8  2010    59       C
# 8            9    8.0     19.0  20.1     61     5    9  2010    61      PS
# 9           10   30.5    194.0   8.6     69     5   10  2010    69       S
# 10          11    7.0      NaN   6.9      C     5   11  2010    74       C
# ...

# %%
weather_data.isna().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       7
# Wind          0
# Temp C        0
# Month         0
# Day           0
# Year          0
# Temp          0
# Weather       3
# dtype: int64

# %%
7/158
# Out:
# 0.04430379746835443

# %% [markdown]
# ## lets assume client approved to drop 5 observations of Solar.R fdeatures and Weather.

# %%
weather_data['Solar.R'].dropna(inplace=True)

# %%
weather_data.isna().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       7
# Wind          0
# Temp C        0
# Month         0
# Day           0
# Year          0
# Temp          0
# Weather       3
# dtype: int64

# %%
weather_data['Weather'].mode()
# Out:
# 0    S
# dtype: object

# %%
weather_data['Weather'].value_counts()
# Out:
# S     59
# C     49
# PS    47
# Name: Weather, dtype: int64

# %% [markdown]
# ## step 2 - data type converson -

# %%
weather_data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
del weather_data['Temp C']

# %%
weather_data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
weather_data.head(30)
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0            1   41.0    190.0   7.4     5    1  2010    67       S
# 1            2   36.0    118.0   8.0     5    2  2010    72       C
# 2            3   12.0    149.0  12.6     5    3  2010    74      PS
# 3            4   18.0    313.0  11.5     5    4  2010    62       S
# 4            5   30.5      NaN  14.3     5    5  2010    56       S
# 5            6   28.0      NaN  14.9     5    6  2010    66       C
# 6            7   23.0    299.0   8.6     5    7  2010    65      PS
# 7            8   19.0     99.0  13.8     5    8  2010    59       C
# 8            9    8.0     19.0  20.1     5    9  2010    61      PS
# 9           10   30.5    194.0   8.6     5   10  2010    69       S
# 10          11    7.0      NaN   6.9     5   11  2010    74       C
# 11          12   16.0    256.0   9.7     5   12  2010    69      PS
# 12          13   11.0    290.0   9.2     5   13  2010    66       S
# ...

# %%
weather_data['Month'] = pd.to_numeric(weather_data['Month'],errors = 'coerce')#.astype(int)

# %%
weather_data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Month         float64
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
weather_data['Month'].fillna(value = 5,inplace = True)

# %%
weather_data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Month         float64
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
weather_data['Month']= weather_data['Month'].astype(int)

# %%
weather_data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Month           int32
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
weather_data.head(50)
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0            1   41.0    190.0   7.4      5    1  2010    67       S
# 1            2   36.0    118.0   8.0      5    2  2010    72       C
# 2            3   12.0    149.0  12.6      5    3  2010    74      PS
# 3            4   18.0    313.0  11.5      5    4  2010    62       S
# 4            5   30.5      NaN  14.3      5    5  2010    56       S
# 5            6   28.0      NaN  14.9      5    6  2010    66       C
# 6            7   23.0    299.0   8.6      5    7  2010    65      PS
# 7            8   19.0     99.0  13.8      5    8  2010    59       C
# 8            9    8.0     19.0  20.1      5    9  2010    61      PS
# 9           10   30.5    194.0   8.6      5   10  2010    69       S
# 10          11    7.0      NaN   6.9      5   11  2010    74       C
# 11          12   16.0    256.0   9.7      5   12  2010    69      PS
# 12          13   11.0    290.0   9.2      5   13  2010    66       S
# ...

# %% [markdown]
# ## 3. Data type transformation

# %% [markdown]
# ### There are 2 transformation techniques Discrete vs Continious
#
# * **1. Discrete - Label encoding / One Hot encoding.**
# * **2. Continious - MinMax Scaler / Standard Scalar / Roburst Scaler**

# %%
weather_data.head(20)
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0            1   41.0    190.0   7.4      5    1  2010    67       S
# 1            2   36.0    118.0   8.0      5    2  2010    72       C
# 2            3   12.0    149.0  12.6      5    3  2010    74      PS
# 3            4   18.0    313.0  11.5      5    4  2010    62       S
# 4            5   30.5      NaN  14.3      5    5  2010    56       S
# 5            6   28.0      NaN  14.9      5    6  2010    66       C
# 6            7   23.0    299.0   8.6      5    7  2010    65      PS
# 7            8   19.0     99.0  13.8      5    8  2010    59       C
# 8            9    8.0     19.0  20.1      5    9  2010    61      PS
# 9           10   30.5    194.0   8.6      5   10  2010    69       S
# 10          11    7.0      NaN   6.9      5   11  2010    74       C
# 11          12   16.0    256.0   9.7      5   12  2010    69      PS
# 12          13   11.0    290.0   9.2      5   13  2010    66       S
# ...

# %% [markdown]
# ## 1. Label encoding

# %%
weather_data_2 = weather_data.copy()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
weather_data_2['Weather']= le.fit_transform(weather_data['Weather'])
weather_data_2
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Month  Day  Year  Temp  Weather
# 0             1   41.0    190.0   7.4      5    1  2010    67        2
# 1             2   36.0    118.0   8.0      5    2  2010    72        0
# 2             3   12.0    149.0  12.6      5    3  2010    74        1
# 3             4   18.0    313.0  11.5      5    4  2010    62        2
# 4             5   30.5      NaN  14.3      5    5  2010    56        2
# ..          ...    ...      ...   ...    ...  ...   ...   ...      ...
# 153         154   41.0    190.0   7.4      5    1  2010    67        0
# 154         155   30.0    193.0   6.9      9   26  2010    70        1
# 155         156   30.5    145.0  13.2      9   27  2010    77        2
# 156         157   14.0    191.0  14.3      9   28  2010    75        2
# 157         158   18.0    131.0   8.0      9   29  2010    76        0
#
# [158 rows x 9 columns]
